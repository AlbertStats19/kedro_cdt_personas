# %%
import pandas as pd
import numpy as np
import logging
from scipy import stats
from io import StringIO
import logging

# %%
import os
os.chdir("/home/sagemaker-user/data-bbog-integration-fabrica-personas/src")
import data_bbog_integration_fabrica_personas.pipelines.feature.nodes as feature
import data_bbog_integration_fabrica_personas.pipelines.backtesting.nodes as backtesting
import data_bbog_integration_fabrica_personas.pipelines.modelo_360.nodes as model_360

# %%
logging.basicConfig()
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Create a string buffer to capture log output
log_capture_string = StringIO()
ch = logging.StreamHandler(log_capture_string)
ch.setLevel(logging.INFO)
logger.addHandler(ch)

# %%
# %load_ext kedro.ipython
# Out:
# [03/25/25 17:27:50] INFO     Resolved project path as:                                              ]8;id=23688;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=427515;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/ipython/__init__.py#139\139]8;;\
#                              /home/sagemaker-user/data-bbog-integration-fabrica-personas.
#                              To set a different path, run '%reload_kedro <project_root>'
# [03/25/25 17:27:51] WARNING  /home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-p ]8;id=43604;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/warnings.py\warnings.py]8;;\:]8;id=729196;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/warnings.py#109\109]8;;\
#                              ackages/kedro/io/data_catalog.py:301: KedroDeprecationWarning:
# ...

# %%
params1= catalog.list
params = catalog.load("parameters")
#params
# Out:
#                     INFO     Loading data from 'parameters' (MemoryDataset)...                  ]8;id=82172;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=977922;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py#502\502]8;;\

# %% [markdown]
# ### Capa Feature

# %%
from typing import Dict, Any , Tuple ,List

# %%
master_primary_fp = catalog.load('master_primary_fp')
# Out:
# [03/25/25 18:40:12] INFO     Loading data from 'master_primary_fp' (ParquetDataSet)...          ]8;id=314528;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=315919;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py#502\502]8;;\

# %%
new_columns = []
for col in list(params['crear_nuevas_variables'].keys()):
    new_columns.append(params['crear_nuevas_variables'][col]['nombre'])
new_columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'mes',
#     'AAAA',
#     'sum_saldo_activos',
#     'sum_saldo_pasivos',
#     'delta_ah_sum_monto_trx_credito',
#     'delta_ah_sum_monto_trx_debito',
#     'delta_tc_sum_facturacion_total',
#     'num_activos_prev',
#     'num_pasivos_prev',
#     'num_prod_activos',
#     'num_prod_pasivos'
# ]

# %%
feature_df = feature.calculate_new_variables_pd(master_primary_fp,params)
# Out:
# [03/25/25 18:47:04] INFO     Se construyo la variable "mes" con exito!                                  ]8;id=144541;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=418583;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#84\84]8;;\
# [03/25/25 18:47:18] INFO     Se construyo la variable "AAAA" con exito!                                 ]8;id=264590;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=581974;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#84\84]8;;\
# ...

# %%
model_homologacion_regiones = feature.modelo_homologacion_regiones(params)
# Out:
#                     INFO     Guardando el pickle de como se homologan las regiones...                  ]8;id=36641;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=690280;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#104\104]8;;\

# %%
model_homologacion_regiones = catalog.load('homologate_region_model')
# Out:
#                     INFO     Loading data from 'homologate_region_model' (PickleDataSet)...     ]8;id=475931;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=307116;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py#502\502]8;;\

# %%
homolog_columns = []
for col in list(params['homologacion_x_variable'].keys()):
    homolog_columns.append(params['homologacion_x_variable'][col]['nombre'])
homolog_columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ['region', 'ocupacion2', 'mar_status2', 'grupo_etario2', 'region3']

# %%
params['homologacion_x_variable'].keys()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# dict_keys(['variable1', 'variable2', 'variable3', 'variable4', 'variable5'])

# %%
homologate_region_df = feature.homologate_region(feature_df,model_homologacion_regiones)
# Out:
# [03/25/25 18:47:44] INFO     La nulidad se remplazara con Other_Region antes de la capa de model_input ]8;id=834967;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=442964;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#141\141]8;;\
# [03/25/25 18:47:47] INFO     Ok la homologacion de la variable region con departamento                 ]8;id=650140;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=203743;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#144\144]8;;\
# ...

# %%
# mirando variables categoricas
view = homologate_region_df.select_dtypes(include=['object','string'])
for col in view:
    if col != params['id']:
        display(view[col].value_counts())
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# generacion
# _millennial      6141137
# _generacion_x    2509692
# _baby_boomer     1157107
# _centennial       398644
# Name: count, dtype: int64
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# departamento
# bogota_d_c_                                 2478349
# antioquia                                   1140432
# valle_del_cauca                             1071861
# cundinamarca                                 793437
# atlantico                                    565631
# santander                                    558519
# tolima                                       313104
# bolivar                                      295387
# norte_de_santander                           283322
# boyaca                                       282733
# ...

# %%
# variables que se eliminaran
params['cols_to_drop']
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ['aa_ciudad', 'segmento_cliente', 'mono_multi_prod', 'seg_comercial']

# %%
feature_df_filt = feature.eliminar_columnas(homologate_region_df, params)
# Out:
# [03/12/25 13:44:03] INFO     Segun la parametrizacion de la Fabrica se eliminara: ['mono_multi_prod',  ]8;id=389887;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=651852;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#173\173]8;;\
#                              'seg_comercial', 'aa_ciudad', 'segmento_cliente']
# [03/12/25 13:44:13] INFO     Tamaño de mi df: (10206580, 267)                                          ]8;id=478353;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=604010;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#176\176]8;;\

# %%
feature_preprocesado_df = feature.preprocesar_feature_df(feature_df_filt, params)
# Out:
#                     INFO     Iniciando el preprocesamiento (LabelEncoder) del DataFrame...             ]8;id=515446;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=611320;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#193\193]8;;\
# [03/11/25 21:39:12] INFO     Iniciando el preprocesamiento (Completitud) del DataFrame...              ]8;id=876278;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=748663;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#208\208]8;;\

# %%
X_feature, y_feature = feature.separar_características(feature_preprocesado_df, params)
# Out:
# [03/11/25 21:40:46] INFO     Separando características y la variable objetivo...                       ]8;id=156550;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=400227;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#240\240]8;;\
#                     INFO     Columna objetivo: viv_cant_ap_group3                                      ]8;id=293726;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=895696;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#250\250]8;;\
# ...

# %%
params['bootstrapping_feature']['N_Iter'] = 5
params['bootstrapping_feature']
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {'N_Iter': 5, 'by_order': True, 'test_size': 0.2}

# %%
# %%time
X_feature = catalog.load('X_feature')
y_feature = catalog.load('y_feature')
# Out:
# [03/25/25 17:28:33] INFO     Loading data from 'X_feature' (ParquetDataSet)...                  ]8;id=820143;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=564873;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py#502\502]8;;\
# [03/25/25 17:33:24] INFO     Loading data from 'y_feature' (ParquetDataSet)...                  ]8;id=399491;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=341378;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py#502\502]8;;\
# CPU times: user 2min 44s, sys: 5min 58s, total: 8min 42s
# Wall time: 4min 55s

# %%
# %%time
importance_df = feature.calcular_importancia(X_feature, y_feature, params)
# Out:
# [03/25/25 17:33:28] INFO     Calculando la importancia de las características usando XGBoost...        ]8;id=537074;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=658536;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#279\279]8;;\
# [03/25/25 17:38:03] INFO     Bootstrapping en la iteración 0 de 5. Ejecución al 0.0%                   ]8;id=336793;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=885736;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#312\312]8;;\
# ...

# %%
importance_df.to_parquet(f's3://data-bbog-dev-sandbox-entity/casos-uso/fabrica-personas/FID/04-feature/lista_importance_df_new_t3.parquet')

# %%
#params['requered_importances']['ignore_importance_model'] = False
#params['requered_importances']['n_top_select_importance_model'] = 25

# %%
feature_selected_list = feature.seleccionar_características(importance_df, feature_df, params)
feature_selected_list.head()
# Out:
# [03/25/25 18:51:09] INFO     Seleccionando las  25 características más importantes                     ]8;id=825447;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=131413;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#356\356]8;;\
#                     INFO     Agregando 1 variables extras a las 25 características más importantes     ]8;id=674726;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=857005;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#358\358]8;;\
# ...

# %%
# print no deberia imprimir nada
if params['requered_importances']['ignore_importance_model'] == False:
    for col in params['requered_importances']['add_variables']:
        if col not in feature_selected_list['Feature'].values:
            print(col)
else:
    for col in params['requered_importances']['variables_select']:
        if col not in feature_selected_list['Feature'].values:
            print(col)

# %%
feature_selected_list.to_parquet(f's3://data-bbog-dev-sandbox-entity/casos-uso/fabrica-personas/FID/04-feature/feature_selected_list_new_t3.parquet')

# %%
master_feature_fp = feature.filtrar_columnas_df(homologate_region_df, feature_selected_list,params)
# Out:
# [03/25/25 18:51:38] INFO     Filtrando columnas del DataFrame basado en la importancia de              ]8;id=499953;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=879210;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#397\397]8;;\
#                              características...
#                     INFO     Inputs seleccionados: ['sum_saldo_activos', 'periodo',                    ]8;id=933377;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py\nodes.py]8;;\:]8;id=103549;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/feature/nodes.py#401\401]8;;\
#                              'num_prod_activos', 'ah_sum_saldo_corte',
# ...

# %%
master_feature_fp.to_parquet(f's3://data-bbog-dev-sandbox-entity/casos-uso/fabrica-personas/FID/04-feature/master_feature_fp_new_t3.parquet')

# %% [markdown]
# #### Comparativo de Importancias:

# %%
importance_df_comp = pd.merge(importance_df,catalog.load('importance_df'), on = 'Feature', how = 'left')
importance_df_comp=importance_df_comp.set_index('Feature')
importance_df_comp.sort_values(by= 'Importance_x', ascending=False).head(25)
# Out:
# [11/20/24 16:13:39] INFO     Loading data from 'importance_df' (ParquetDataSet)...              ]8;id=924309;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=681818;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py#502\502]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  Importance_x  Importance_y
# Feature
# ah_sum_monto_trx_debito_mean_6       0.664746      0.763767
# ah_cant_prev                         0.078696      0.044756
# ah_cant                              0.033573      0.029755
# ah_sum_monto_trx_debito_mean_3       0.021655      0.001181
# ah_sum_monto_trx_debito_std_3        0.016681      0.031853
# ah_sum_saldo_corte                   0.015838      0.012375
# ...

# %%
print('Variables del anterior modelo que ahora no estan:')
best_last_process = importance_df_comp.sort_values(by= 'Importance_y', ascending=False).head(25).index.tolist()
for col in best_last_process:
    if col not in importance_df_comp.sort_values(by= 'Importance_x', ascending=False).head(25).index:
        print(col)
# Out:
# Variables del anterior modelo que ahora no estan:
# fid_cant_prev
# antiguedad_meses
# ah_sum_monto_trx_credito_mean_3
# ah_sum_saldo_promedio_mean_3

# %%
print('Variables del nuevo modelo que no se seleccionaron:')

best_last_process = importance_df_comp.sort_values(by= 'Importance_x', ascending=False).head(25).index.tolist()
for col in best_last_process:
    if col not in importance_df_comp.sort_values(by= 'Importance_y', ascending=False).head(25).index:
        print(col)
# Out:
# Variables del nuevo modelo que no se seleccionaron:
# ah_sum_monto_trx_debito_mean_3
# sum_saldo_pasivos
# ah_sum_cantidad_trx_credito
# tc_cant
