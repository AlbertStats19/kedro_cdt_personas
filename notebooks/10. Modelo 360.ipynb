# %%
import pandas as pd
import numpy as np
import logging
from scipy import stats
from io import StringIO
import logging

# %%
import os
os.chdir("/home/sagemaker-user/data-bbog-integration-fabrica-personas/src")
import data_bbog_integration_fabrica_personas.pipelines.feature.nodes as feature
import data_bbog_integration_fabrica_personas.pipelines.backtesting.nodes as backtesting
import data_bbog_integration_fabrica_personas.pipelines.modelo_360.nodes as model_360

# %%
logging.basicConfig()
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Create a string buffer to capture log output
log_capture_string = StringIO()
ch = logging.StreamHandler(log_capture_string)
ch.setLevel(logging.INFO)
logger.addHandler(ch)

# %%
# %load_ext kedro.ipython
# Out:
# [03/12/25 17:35:27] INFO     Resolved project path as:                                              ]8;id=390689;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=411115;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/ipython/__init__.py#139\139]8;;\
#                              /home/sagemaker-user/data-bbog-integration-fabrica-personas.
#                              To set a different path, run '%reload_kedro <project_root>'
# [03/12/25 17:35:28] WARNING  /home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-p ]8;id=894186;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/warnings.py\warnings.py]8;;\:]8;id=940640;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/warnings.py#109\109]8;;\
#                              ackages/kedro/io/data_catalog.py:301: KedroDeprecationWarning:
# ...

# %%
params1= catalog.list
params = catalog.load("parameters")
#params
# Out:
#                     INFO     Loading data from 'parameters' (MemoryDataset)...                  ]8;id=241096;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=438719;file:///home/sagemaker-user/.conda/envs/proyecto_fabrica/lib/python3.9/site-packages/kedro/io/data_catalog.py#502\502]8;;\

# %% [markdown]
# ### 1. nodos

# %% [markdown]
# ##### 1.1 Cargar bases, normaliza y concatena

# %%
# Python function that loads a parquet from a path
def load_parquet(path):
    return pd.read_parquet(path)

# Python function that loads csv from a path
def load_csv(path):
    return pd.read_csv(path)

# %% [markdown]
# # Flujo del modelo 360

# %%
inputs_df,total_clientes = model_360.anexos_modelo_360(params)
inputs_df.head()
# Out:
# IOStream.flush timed out
# [03/12/25 17:40:22] INFO     Iniciando con los calculos de las variables anexas a la entrega del modelo ]8;id=104628;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py\nodes.py]8;;\:]8;id=730474;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py#89\89]8;;\
# ['periodo', 'hashvalue1', 'vlr_ing_bru_mes', 'departamento']
#                     INFO     Mes insumo de los pronosticos: 202501                                     ]8;id=600282;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py\nodes.py]8;;\:]8;id=527014;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py#102\102]8;;\
# ...

# %%
total_clientes.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      hashvalue1  lib_cant
# 0  CC1000000683         0
# 1  CC1000003404         0
# 2  CC1000004875         0
# 3  CC1000007593         0
# 4  CC1000008018         0

# %%
from typing import Dict, List, Any, Tuple
from io import StringIO

import s3fs
import warnings
import pickle

import re
from scipy import stats
import pandas as pd
import polars as pl
import numpy as np
import logging
from IPython.display import display

import os
import data_bbog_integration_fabrica_personas.pipelines.feature.nodes as feature
import data_bbog_integration_fabrica_personas.pipelines.backtesting.nodes as backtesting

# %%
params['multiplicar_recall_probs'] = False
params['metodo_estandarizar_probs'] = 'Min-Max'
params['reprocesar_probs_norm']  = True
params['productos_carpeta'] = ["CDT",'libranza']

# %%
#propension_adq_productos = cargar_bases(clientes_lib,params)
propension_adq_productos = model_360.cargar_bases(total_clientes,params)
propension_adq_productos.head(4)
# Out:
# [03/12/25 17:41:00] INFO     Empezando la creacion de la base de campaña. Vigencia del archivo: 202404 ]8;id=358657;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py\nodes.py]8;;\:]8;id=989946;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py#188\188]8;;\
#                     INFO     ------------                                                              ]8;id=436045;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py\nodes.py]8;;\:]8;id=940545;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py#200\200]8;;\
# ...

# %%
from data_bbog_integration_fabrica_personas.pipelines.modelo_360.nodes import adjust_format
from data_bbog_integration_fabrica_personas.pipelines.modelo_360.nodes import extraer_variable_x_producto
from data_bbog_integration_fabrica_personas.pipelines.modelo_360.nodes import optimizando_propension
from data_bbog_integration_fabrica_personas.pipelines.modelo_360.nodes import guardando_ordenamiento_optimo

# %%
# se pone esta ruta porque el nodo guarda automaticamente backups
params['ruta_save'] = 's3://data-bbog-dev-sandbox-entity/casos-uso/fabrica-personas/modelo_360/campana_prueba.parquet'
campana_permanente = model_360.reshape_dataframe(propension_adq_productos,params)
# Out:
# [03/12/25 17:41:48] INFO     Generando la tabla dinamica..                                             ]8;id=800894;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py\nodes.py]8;;\:]8;id=431857;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py#704\704]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                             count       mean       std        min        25%  \
# product   segment
# CDT       Alto          4000000.0   5.164061  0.629334   4.184398   4.574312
#           Bajo         61617600.0   0.141929  0.009071   0.127791   0.133910
#           Medio        30808800.0   0.215095  0.010491   0.199642   0.206041
#           Medio Alto   53617500.0   0.804927  0.854750   0.237262   0.285801
# ...

# %%
campana_permanente.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              probabilidad_1 probabilidad_2 producto_1 producto_2 propension_1  \
# CC1193238197       0.158548       0.003551  RETANQUEO        CDT   Medio Alto
# CC1193240528       0.158593       0.019316   LIBRANZA        CDT     Muy Alto
# CC1193239841       0.158505       0.002002   LIBRANZA        CDT   Medio Alto
# CC1066182588       0.158583       0.002217  RETANQUEO        CDT     Muy Alto
# CC41885193         0.025025       0.158404        CDT   LIBRANZA   Medio Alto
#
#              propension_2 decil_1 decil_2 propension_360
# CC1193238197   Medio Alto    10.0    10.0              7
# CC1193240528   Medio Alto    10.0    10.0              7
# CC1193239841        Medio    10.0     8.0              7
# CC1066182588        Medio    10.0     9.0              7
# CC41885193          Medio    10.0     9.0              7

# %%
for col in ['producto_1','producto_2','producto_3','producto_4','producto_5','producto_6','producto_7','producto_8']:
    if col in campana_permanente.columns:
        print(col,campana_permanente[col].unique())
# Out:
# producto_1 ['RETANQUEO' 'LIBRANZA' 'CDT']
# producto_2 ['CDT' 'LIBRANZA' 'RETANQUEO']

# %%
campana2 = model_360.union_frames(campana_permanente,inputs_df,params)
# Out:
# [03/12/25 17:52:59] INFO     Unificando Modelo 360 con las variables anexos...                         ]8;id=687466;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py\nodes.py]8;;\:]8;id=487880;file:///home/sagemaker-user/data-bbog-integration-fabrica-personas/src/data_bbog_integration_fabrica_personas/pipelines/modelo_360/nodes.py#895\895]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      hashvalue1      DEFINIT probabilidad_1 probabilidad_2 producto_1  \
# 0  CC1193238197  C1193238197       0.158548       0.003551  RETANQUEO
# 1  CC1193240528  C1193240528       0.158593       0.019316   LIBRANZA
# 2  CC1193239841  C1193239841       0.158505       0.002002   LIBRANZA
# 3  CC1066182588  C1066182588       0.158583       0.002217  RETANQUEO
# ...

# %%
campana2.head(3)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      hashvalue1      DEFINIT probabilidad_1 probabilidad_2 producto_1  \
# 0  CC1193238197  C1193238197       0.158548       0.003551  RETANQUEO
# 1  CC1193240528  C1193240528       0.158593       0.019316   LIBRANZA
# 2  CC1193239841  C1193239841       0.158505       0.002002   LIBRANZA
#
#   producto_2 propension_1 propension_2 decil_1 decil_2 propension_360  \
# 0        CDT   Medio Alto   Medio Alto    10.0    10.0              7
# 1        CDT     Muy Alto   Medio Alto    10.0    10.0              7
# 2        CDT   Medio Alto        Medio    10.0     8.0              7
#
#             region  decil_ingreso categoria
# 0    Region_Caribe            7.0         2
# 1  Region_Pacifica            6.0         2
# 2  Region_Pacifica            7.0         2
